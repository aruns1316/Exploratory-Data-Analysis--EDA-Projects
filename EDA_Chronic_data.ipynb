# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/kidney_disease (2).csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 395  ...   47  6700  4.9   no  no   no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# 397  ...   49  6600  5.4   no  no   no  good  no  no         notckd
# 398  ...   51  7200  5.9   no  no   no  good  no  no         notckd
# 399  ...   53  6800  6.1   no  no   no  good  no  no         notckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.drop('id',axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
df['pcv']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: pcv, Length: 400, dtype: object

# %%
df['pcv'].isna().sum()
# Out:
# 70

# %%
df['pcv'] = pd.to_numeric(df['pcv'], errors = 'coerce')

# %%
df['pcv']
# Out:
# 0      44.0
# 1      38.0
# 2      31.0
# 3      32.0
# 4      35.0
#        ...
# 395    47.0
# 396    54.0
# 397    49.0
# 398    51.0
# 399    53.0
# Name: pcv, Length: 400, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              295 non-null    object
# ...

# %%
#to_numeric convert object into float value.

df['wc'] = pd.to_numeric(df['wc'], errors = 'coerce')
df['rc'] = pd.to_numeric(df['rc'], errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              294 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
categorical_cols = [col for col in df.columns if df[col].dtype == 'O']
numerical_cols = [col for col in df.columns if df[col].dtype != 'O']

# %%
categorical_cols
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
for col in categorical_cols:
  print(f'{col} has {(df[col].unique())} values \n')
# Out:
# rbc has [nan 'normal' 'abnormal'] values
#
# pc has ['normal' 'abnormal' nan] values
#
# pcc has ['notpresent' 'present' nan] values
#
# ba has ['notpresent' 'present' nan] values
#
# htn has ['yes' 'no' nan] values
#
# dm has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# cad has ['no' 'yes' '\tno' nan] values
#
# appet has ['good' 'poor' nan] values
#
# pe has ['no' 'yes' nan] values
#
# ane has ['no' 'yes' nan] values
#
# classification has ['ckd' 'ckd\t' 'notckd'] values

# %%
#replace unwanted values

df['dm'].replace(to_replace = (' yes', 'yes', '\tno', '\tyes'),inplace = True)

# %%
df['dm'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['cad'] = df['cad'].replace(to_replace=r'\tno', value='no', inplace=True)

# %%
df['cad'].unique()
# Out:
# array([None], dtype=object)

# %%
df['classification'] = df['classification'].replace(to_replace=r'ckd\t', value='ckd', regex=True)

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'notckd'], dtype=object)

# %%
df['classification'] = df['classification'].map({'ckd': 0, 'notckd': 1})

# %%
df['classification'].unique()
# Out:
# array([0, 1])

# %%
for col in categorical_cols:
  print(f'{col} has {(df[col].unique())} values \n')
# Out:
# rbc has [nan 'normal' 'abnormal'] values
#
# pc has ['normal' 'abnormal' nan] values
#
# pcc has ['notpresent' 'present' nan] values
#
# ba has ['notpresent' 'present' nan] values
#
# htn has ['yes' 'no' nan] values
#
# dm has ['yes' 'no' nan] values
#
# cad has [None] values
#
# appet has ['good' 'poor' nan] values
#
# pe has ['no' 'yes' nan] values
#
# ane has ['no' 'yes' nan] values
#
# classification has [0 1] values

# %%
#Univariate

plt.figure(figsize = (10,6))
sns.histplot(df['age'].dropna(), kde = True, bins = 20, color = 'skyblue')
plt.title('Distribution of the Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#insights >> distribution of age is right skewed.

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['htn']
# Out:
# 0      yes
# 1       no
# 2       no
# 3      yes
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: htn, Length: 400, dtype: object

# %%
sns.countplot(x = 'htn', data = df, palette = 'viridis')
# Out:
# <Axes: xlabel='htn', ylabel='count'>

# %%
#insights >> Based on the graph almost 150 has hybertension (htn).

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.boxplot(x = 'classification', y = 'bu', data = df, palette = 'viridis')
plt.title('Blood_Urea')
# Out:
# Text(0.5, 1.0, 'Blood_Urea')

# %%
#insights >> outliers

# %%
sns.violinplot(x = 'classification', y = 'sc', data = df, palette = 'muted')
plt.title('serum creatinine')
# Out:
# Text(0.5, 1.0, 'serum creatinine')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(x='ane', data=df, palette='muted')
plt.title('Aanemia')
# Out:
# Text(0.5, 1.0, 'Aanemia')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['appet']
# Out:
# 0      good
# 1      good
# 2      poor
# 3      poor
# 4      good
#        ...
# 395    good
# 396    good
# 397    good
# 398    good
# 399    good
# Name: appet, Length: 400, dtype: object

# %%
df['appet'].value_counts()
# Out:
# appet
# good    317
# poor     82
# Name: count, dtype: int64

# %%
#pie chart

df['appet'].value_counts().plot.pie(autopct = "%1.1f%%" , colors = ['lightcoral','lightgreen'], explode = [0,0.1],startangle = 90, shadow = True)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(x = 'pcc', data = df, palette = 'muted')
plt.title('Pus cell clumps')
# Out:
# Text(0.5, 1.0, 'Pus cell clumps')

# %%
#insights >> this pus cell clumps are present in 40-45 peoples.

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.histplot(df['wc'].dropna(), bins = 20, kde = True, color = 'darkorange')
# Out:
# <Axes: xlabel='wc', ylabel='Count'>

# %%
#insights >> there are outliers.

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['dm']
# Out:
# 0      yes
# 1       no
# 2       no
# 3       no
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: dm, Length: 400, dtype: object

# %%
df['dm'].value_counts().plot.pie(autopct="%1.1f%%", wedgeprops = dict(width = 0.03))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(x ='pe', data = df, palette = 'muted')
plt.title('peda_edema')
# Out:
# Text(0.5, 1.0, 'peda_edema')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(x = 'ba' , data = df, palette = 'muted')
# Out:
# <Axes: xlabel='ba', ylabel='count'>

# %%
#bivariate analysis

sns.scatterplot(x = 'age', y = 'bp', data = df)
plt.title('Blood pressure')
# Out:
# Text(0.5, 1.0, 'Blood pressure')

# %%
sns.scatterplot(x = 'age', y = 'bp', data = df, hue = 'classification', palette = 'coolwarm')
plt.title('Blood pressure')
# Out:
# Text(0.5, 1.0, 'Blood pressure')

# %%
#insights >> as age is increasing blood pressure is inscreasing.

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.boxplot(x = 'pcc', y = 'al', data = df)
plt.title('albumim')
# Out:
# Text(0.5, 1.0, 'albumim')

# %%
sns.violinplot(x = 'pcc', y = 'al', data = df, inner = 'quartile')
plt.title('albumim')
# Out:
# Text(0.5, 1.0, 'albumim')

# %%
#Stacked bar chart

pcc_hypertension = pd.crosstab(df['pcc'], df['htn'])

# %%
pcc_hypertension
# Out:
# htn          no  yes
# pcc
# notpresent  232  120
# present      15   27

# %%
pcc_hypertension.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='pcc'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
#multivariate analysis

cols = ['age','bp','bgr','sc','classification']

g = sns.PairGrid(df[cols], hue = 'classification', palette = 'muted')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, cmap = 'Blues_d')
g.map_diag(sns.histplot)
g.add_legend()
plt.title('Paid grid for selected columns')
plt.show()

# %%
cols = ['age','bp','bgr','sc','classification']
sns.pairplot(df[cols], hue = 'classification', palette = 'muted')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.corr(numeric_only = True)
# Out:
#                      age        bp        sg        al        su       bgr  \
# age             1.000000  0.159480 -0.191096  0.122091  0.220866  0.244992
# bp              0.159480  1.000000 -0.218836  0.160689  0.222576  0.160193
# sg             -0.191096 -0.218836  1.000000 -0.469760 -0.296234 -0.374710
# al              0.122091  0.160689 -0.469760  1.000000  0.269305  0.379464
# su              0.220866  0.222576 -0.296234  0.269305  1.000000  0.717827
# bgr             0.244992  0.160193 -0.374710  0.379464  0.717827  1.000000
# bu              0.196985  0.188517 -0.314295  0.453528  0.168583  0.143322
# sc              0.132531  0.146222 -0.361473  0.399198  0.223244  0.114875
# sod            -0.100046 -0.116422  0.412190 -0.459896 -0.131776 -0.267848
# pot             0.058377  0.075151 -0.072787  0.129038  0.219450  0.066966
# hemo           -0.192928 -0.306540  0.602582 -0.634632 -0.224775 -0.306189
# ...

# %%
corr = df.corr(numeric_only = True)
plt.figure(figsize = (10,8))
sns.heatmap(corr , annot = True, cmap = 'coolwarm', linewidth = 0.5)
# Out:
# <Axes: >

# %%
sns.swarmplot(x = 'al', y = 'age', hue = 'htn', data = df, palette = 'muted')
# Out:
# <Axes: xlabel='al', ylabel='age'>

# %%
fig = px.scatter(df, x = 'age', y = 'bp', hover_data = ['sc', 'hemo'])    #hover shows the values in dots.
fig.update_layout(title='Interactive scatter plot with hover information')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df, x = 'age', y = 'bp', z = 'sc')
fig.update_layout(title='Interactive scatter plot with hover information')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

data_corr = df.corr(numeric_only = True)
fig = go.Figure(data = go.Heatmap (z = corr.values,
                             x = data_corr.columns,
                             y = data_corr.index ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.isnull().sum()
# Out:
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                71
# wc                106
# rc                131
# htn                 2
# dm                  2
# cad               400
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
categorical_cols
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
numerical_cols
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc']

# %%
#replace with median

median_values = df[numerical_cols].median()

# %%
median_values
# Out:
# age       55.00
# bp        80.00
# sg         1.02
# al         0.00
# su         0.00
# bgr      121.00
# bu        42.00
# sc         1.30
# sod      138.00
# pot        4.40
# hemo      12.65
# pcv       40.00
# wc      8000.00
# rc         4.80
# dtype: float64

# %%
df_numerical_cols = df[numerical_cols].fillna(median_values)

# %%
df_numerical_cols
# Out:
#       age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0    48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  138.0  4.4  15.4  44.0
# 1     7.0  50.0  1.020  4.0  0.0  121.0  18.0  0.8  138.0  4.4  11.3  38.0
# 2    62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  138.0  4.4   9.6  31.0
# 3    48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2  32.0
# 4    51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  138.0  4.4  11.6  35.0
# ..    ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...   ...
# 395  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7  47.0
# 396  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5  54.0
# 397  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8  49.0
# 398  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2  51.0
# 399  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8  53.0
#
#          wc   rc
# 0    7800.0  5.2
# 1    6000.0  4.8
# ...

# %%
df[numerical_cols].isna().sum()
# Out:
# age       9
# bp       12
# sg       47
# al       46
# su       49
# bgr      44
# bu       19
# sc       17
# sod      87
# pot      88
# hemo     52
# pcv      71
# wc      106
# rc      131
# dtype: int64

# %%
mode_values = df.mode().iloc[0]
df[categorical_cols] = df[categorical_cols].fillna(mode_values)

# %%
df[categorical_cols].isna().sum()
# Out:
# rbc                 0
# pc                  0
# pcc                 0
# ba                  0
# htn                 0
# dm                  0
# cad               400
# appet               0
# pe                  0
# ane                 0
# classification      0
# dtype: int64

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                float64
# rc                float64
# htn                object
# dm                 object
# cad               float64
# appet              object
# pe                 object
# ane                object
# classification      int64
# dtype: object

# %%
#incoding

from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

LabelEncoder = LabelEncoder()
for col in categorical_cols: # Changed 'categorial_cols' to 'categorical_cols'
  df[col] = LabelEncoder.fit_transform(df[col])

# %%
df.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv      wc  \
# 0  48.0  80.0  1.020  1.0  0.0    1   1    0   0  121.0  ...  44.0  7800.0
# 1   7.0  50.0  1.020  4.0  0.0    1   1    0   0    NaN  ...  38.0  6000.0
# 2  62.0  80.0  1.010  2.0  3.0    1   1    0   0  423.0  ...  31.0  7500.0
# 3  48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 4  51.0  80.0  1.010  2.0  0.0    1   1    0   0  106.0  ...  35.0  7300.0
#
#     rc  htn  dm  cad  appet  pe  ane  classification
# 0  5.2    1   1    0      0   0    0               0
# 1  NaN    0   0    0      0   0    0               0
# 2  NaN    0   0    0      1   0    1               0
# 3  3.9    1   0    0      1   1    1               0
# 4  4.6    0   0    0      0   0    0               0
#
# [5 rows x 25 columns]
